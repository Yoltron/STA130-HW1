# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2. When we do a process called "hypothesis testing", we first create a "hypothesis" called the null hypothesis. To determine if the null hypothesis is true, we perform test, who's outcome refer to to values such as the mean, standard deviation, etc of the entire population, which are called population parameters, while the sample statistics refer to the same things (mean, stand dev), but of a given sample. (Which we do not test for)

# %%
4. Given a null hypothesis, we construct a sampling distribution where the null hypothesis is true. 
Then we place compare the sampling distribution of a desired statistic of our original dataset, and count the proportion of it
that counts as "extreme" under the new sampling distribution (far right or far left). This is the p-value
hence a low p-value means that under the null hypoMthesis, our old data is more extreme (or less likely to occur)
hence the null hypothesis is more ridiculous
# Out:
#   Cell In[7], line 1
#     4. Given a null hypothesis, we construct a sampling distribution where the null hypothesis is true.
#        ^
# SyntaxError: invalid syntax

# %%
6. The p-value cannot be considered low enough unless we have a declared a significance level beforehand 
(only if the p value is smaller than the significance level can we declare the null hypothesis to be false)

# %%
https://chatgpt.com/share/670f37b6-b2a8-8000-8914-95a1ddf10e3e

# %%
# Out:
# <div>                            <div id="c2988ff2-16ac-4166-93b7-9188623ed3e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2988ff2-16ac-4166-93b7-9188623ed3e6")) {                    Plotly.newPlot(                        "c2988ff2-16ac-4166-93b7-9188623ed3e6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sample Mean=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[1.0026800724032752,1.0125932587892492,1.0644148976992298,0.9827810173899136,0.985470598920295,0.9439773903799271,1.059718265005868,1.0121193999543994,0.9589666231899291,0.9980567
# ...
